# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('activity2_companies.csv')

# %%
df[['Employee Size', 'Revenue']].describe()
# Out:
#        Employee Size       Revenue
# count    1644.000000  1.644000e+03
# mean      598.908151  1.154333e+08
# std      1500.989831  1.238567e+08
# min         7.000000  5.100000e+06
# 25%       125.000000  3.737500e+07
# 50%       350.000000  6.000000e+07
# 75%       560.000000  1.399925e+08
# max     48530.000000  7.000000e+08

# %%
df[['Employee Size', 'Revenue']].median()
# Out:
# Employee Size         350.0
# Revenue          60000000.0
# dtype: float64

# %%
top_10_industry = df.groupby('Industry').agg('Revenue')
top_10_industry.head()
#sns.barplot(data=df, y='Industry', x='Revenue')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 top_10_industry = df.groupby('Industry').agg('Revenue').sort_values(ascending=False)
#       2 top_10_industry.head()
#       3 #sns.barplot(data=df, y='Industry', x='Revenue')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\groupby\groupby.py:1363, in GroupBy.__getattr__(self, attr)
#    1360 if attr in self.obj:
#    1361     return self[attr]
# -> 1363 raise AttributeError(
#    1364     f"'{type(self).__name__}' object has no attribute '{attr}'"
#    1365 )
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'sort_values'

# %%
sns.heatmap(data= df[['Revenue','Employee Size']].corr(),vmin=-1, vmax=1, annot=True, cmap='coolwarm')
# Out:
# <Axes: >
